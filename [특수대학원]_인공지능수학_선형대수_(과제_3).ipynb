# %% [markdown]
# <a href="https://colab.research.google.com/github/aa000098/Mathmatics-for-AI/blob/hyunson/%5B%ED%8A%B9%EC%88%98%EB%8C%80%ED%95%99%EC%9B%90%5D_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%88%98%ED%95%99_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%98_(%EA%B3%BC%EC%A0%9C_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 과제 목표
#
# 파이썬 numpy, scipy 패키지를 이용해 주어진 행렬에 대한 LU 분해를 구하는 코드를 작성합니다.
#
# 참고자료: [링크](https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.lu.html)

# %% [markdown]
# ## 행렬 $A$ 정의
#
# 다음의 3x3 행렬 $A$를 정의하는 numpy 코드를 작성하시오.
#
# $$ A =
# \left[
# \begin{array}{rrr}
#  3 &  1 &  1 \\
#  1 & -2 & -1 \\
#  1 &  1 &  1
# \end{array}
# \right]
# $$

# %%
import numpy as np
import scipy.linalg

# %%
# 행렬 코딩

## TODO
A = None

print(A)
print(np.shape(A))
# Out:
# None
# ()

# %% [markdown]
# ## 행렬 $A$의 LU 분해 계산
# 앞서 정의한 행렬 $A$에 대해 LU 분해, $A = PLU$를 수행하는 scipy 코드를 작성하시오.

# %%
# PLU 분해

## TODO
P, L, U = None, None, None

print("P:", P)
print("L:", L)
print("U:", U)

AA = None
print("AA:", AA)
# Out:
# P: None
# L: None
# U: None
# AA: None

# %% [markdown]
# ## 벡터 정의
# 다음의 3-벡터 $\mathbf{b}$를 정의하는 numpy 코드를 작성하시오.
# $$ \mathbf{b} =
# \left[
# \begin{array}{rrr}
#  4 \\
#  1 \\
#  2
# \end{array}
# \right]
# $$

# %%
# 벡터 코딩

## TODO
b = None

print(b)
print(np.shape(b))
# Out:
# None
# ()

# %% [markdown]
# ## LU-분해를 이용해 선형시스템 $A \mathbf{x} = \mathbf{b}$ 풀기
# 행렬 $A$에 대한 LU 분해를 이용해 $A\mathbf{x} = \mathbf{b}$를 계산하는 scipy 코드를 작성하시오.

# %%
# LU 분해

## TODO
lu, piv = None, None
x = None

print("x:", x)
print(np.shape(x))
# Out:
# x: None
# ()

# %% [markdown]
# ## 선형시스템의 해 확인
#
# 앞서 LU 분해를 이용해 구한 $\mathbf{x}$가 선형시스템 $A\mathbf{x} = \mathbf{b}$의 해(solution)로서 알맞게 구한 것인지 검증하는 코드를 작성하시오.
#
# 방법: $A\mathbf{x}$의 연산결과가 $\mathbf{b}$와 충분히 가까운지를 검증한다. [참고자료: [링크](https://numpy.org/doc/stable/reference/generated/numpy.allclose.html)]

# %%
## 결과 검증

# TODO
bb = None

if np.allclose(b, bb):
  print("Ok")
else:
  print("something wrong")
